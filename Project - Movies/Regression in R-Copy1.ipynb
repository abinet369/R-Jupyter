# %%
df=read.csv(file='C:\\Users\\abine\\Dropbox\\Projects\\R Reg ana\\movies.csv',header = TRUE, stringsAsFactors = FALSE)
head(df)
# Out:
#   budget   company                                country director
# 1  8000000 Columbia Pictures Corporation          USA     Rob Reiner
# 2  6000000 Paramount Pictures                     USA     John Hughes
# 3 15000000 Paramount Pictures                     USA     Tony Scott
# 4 18500000 Twentieth Century Fox Film Corporation USA     James Cameron
# 5  9000000 Walt Disney Pictures                   USA     Randal Kleiser
# 6  6000000 Hemdale                                UK      Oliver Stone
#   genre     gross     name                     rating released   runtime score
# 1 Adventure  52287414 Stand by Me              R      1986-08-22  89     8.1
# 2 Comedy     70136369 Ferris Bueller's Day Off PG-13  1986-06-11 103     7.8
# 3 Action    179800601 Top Gun                  PG     1986-05-16 110     6.9
# 4 Action     85160248 Aliens                   R      1986-07-18 137     8.4
# 5 Adventure  18564613 Flight of the Navigator  PG     1986-08-01  90     6.9
# 6 Drama     138530565 Platoon                  R      1987-02-06 120     8.1
#   star              votes  writer        year
# 1 Wil Wheaton       299174 Stephen King  1986
# 2 Matthew Broderick 264740 John Hughes   1986
# 3 Tom Cruise        236909 Jim Cash      1986
# 4 Sigourney Weaver  540152 James Cameron 1986
# 5 Joey Cramer        36636 Mark H. Baker 1986
# 6 Charlie Sheen     317585 Oliver Stone  1986

# %%
summary(df)
# Out:
#      budget            company            country            director
#  Min.   :        0   Length:6820        Length:6820        Length:6820
#  1st Qu.:        0   Class :character   Class :character   Class :character
#  Median : 11000000   Mode  :character   Mode  :character   Mode  :character
#  Mean   : 24581129
#  3rd Qu.: 32000000
#  Max.   :300000000
#     genre               gross               name              rating
#  Length:6820        Min.   :       70   Length:6820        Length:6820
#  Class :character   1st Qu.:  1515839   Class :character   Class :character
#  Mode  :character   Median : 12135679   Mode  :character   Mode  :character
#                     Mean   : 33497829
#                     3rd Qu.: 40065340
#                     Max.   :936662225
#    released            runtime          score           star
#  Length:6820        Min.   : 50.0   Min.   :1.500   Length:6820
#  Class :character   1st Qu.: 95.0   1st Qu.:5.800   Class :character
#  Mode  :character   Median :102.0   Median :6.400   Mode  :character
#                     Mean   :106.6   Mean   :6.375
#                     3rd Qu.:115.0   3rd Qu.:7.100
#                     Max.   :366.0   Max.   :9.300
#      votes            writer               year
#  Min.   :     27   Length:6820        Min.   :1986
#  1st Qu.:   7665   Class :character   1st Qu.:1993
#  Median :  25893   Mode  :character   Median :2001
#  Mean   :  71220                      Mean   :2001
#  3rd Qu.:  75812                      3rd Qu.:2009
#  Max.   :1861666                      Max.   :2016

# %%
str(df)
# Out:
# 'data.frame':	6820 obs. of  15 variables:
#  $ budget  : num  8000000 6000000 15000000 18500000 9000000 6000000 25000000 6000000 9000000 15000000 ...
#  $ company : chr  "Columbia Pictures Corporation" "Paramount Pictures" "Paramount Pictures" "Twentieth Century Fox Film Corporation" ...
#  $ country : chr  "USA" "USA" "USA" "USA" ...
#  $ director: chr  "Rob Reiner" "John Hughes" "Tony Scott" "James Cameron" ...
#  $ genre   : chr  "Adventure" "Comedy" "Action" "Action" ...
#  $ gross   : num  5.23e+07 7.01e+07 1.80e+08 8.52e+07 1.86e+07 ...
#  $ name    : chr  "Stand by Me" "Ferris Bueller's Day Off" "Top Gun" "Aliens" ...
#  $ rating  : chr  "R" "PG-13" "PG" "R" ...
#  $ released: chr  "1986-08-22" "1986-06-11" "1986-05-16" "1986-07-18" ...
#  $ runtime : int  89 103 110 137 90 120 101 120 96 96 ...
#  $ score   : num  8.1 7.8 6.9 8.4 6.9 8.1 7.4 7.8 6.8 7.5 ...
#  $ star    : chr  "Wil Wheaton" "Matthew Broderick" "Tom Cruise" "Sigourney Weaver" ...
#  $ votes   : int  299174 264740 236909 540152 36636 317585 102879 146768 60565 129698 ...
#  $ writer  : chr  "Stephen King" "John Hughes" "Jim Cash" "James Cameron" ...
#  $ year    : int  1986 1986 1986 1986 1986 1986 1986 1986 1986 1986 ...

# %% [markdown]
# From above output we can see that there are 1000 observations or row and 12 variables or columns in imdb dataframe that we created in our first code block.

# %%
df$company<-as.factor(df$company)
df$director<-as.factor(df$director)
df$genre<-as.factor(df$genre)
df$rating<-as.factor(df$rating)
df$star<-as.factor(df$star)
df$writer<-as.factor(df$writer)

# %%
str(df)
# Out:
# 'data.frame':	6820 obs. of  15 variables:
#  $ budget  : num  8000000 6000000 15000000 18500000 9000000 6000000 25000000 6000000 9000000 15000000 ...
#  $ company : Factor w/ 2179 levels "\"DIA\" Productions GmbH & Co. KG",..: 665 1683 1683 2068 2124 1159 1161 763 1683 1936 ...
#  $ country : chr  "USA" "USA" "USA" "USA" ...
#  $ director: Factor w/ 2759 levels "A.R. Murugadoss",..: 2200 1304 2652 1073 2129 1955 1214 590 1011 559 ...
#  $ genre   : Factor w/ 17 levels "Action","Adventure",..: 2 5 1 1 2 7 2 7 5 7 ...
#  $ gross   : num  5.23e+07 7.01e+07 1.80e+08 8.52e+07 1.86e+07 ...
#  $ name    : chr  "Stand by Me" "Ferris Bueller's Day Off" "Top Gun" "Aliens" ...
#  $ rating  : Factor w/ 13 levels "B","B15","G",..: 9 8 7 9 7 9 7 9 8 9 ...
#  $ released: chr  "1986-08-22" "1986-06-11" "1986-05-16" "1986-07-18" ...
#  $ runtime : int  89 103 110 137 90 120 101 120 96 96 ...
#  $ score   : num  8.1 7.8 6.9 8.4 6.9 8.1 7.4 7.8 6.8 7.5 ...
#  $ star    : Factor w/ 2504 levels "'Weird Al' Yankovic",..: 2458 1609 2349 2197 1146 372 529 928 1734 1043 ...
#  $ votes   : int  299174 264740 236909 540152 36636 317585 102879 146768 60565 129698 ...
#  $ writer  : Factor w/ 4199 levels "'Weird Al' Yankovic",..: 3728 1980 1861 1637 2559 2996 981 901 1980 1342 ...
#  $ year    : int  1986 1986 1986 1986 1986 1986 1986 1986 1986 1986 ...

# %% [markdown]
# ## DATA CLEANING

# %% [markdown]
# Let us check the column names in our dataset

# %%
colnames(df)
# Out:
#  [1] "budget"   "company"  "country"  "director" "genre"    "gross"
#  [7] "name"     "rating"   "released" "runtime"  "score"    "star"
# [13] "votes"    "writer"   "year"

# %% [markdown]
# Here two column names at index 8 and 11 looks too long. Let's rename these two.

# %%
library(ggplot2)
library(d3Tree)
library(dplyr)
library(wordcloud)
library(Amelia)
library(corrgram)
library(corrplot)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.6.2"Warning message:
# "package 'd3Tree' was built under R version 3.6.3"Warning message:
# "package 'dplyr' was built under R version 3.6.2"
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
# Warning message:
# "package 'wordcloud' was built under R version 3.6.3"Loading required package: RColorBrewer
# Warning message:
# "package 'Amelia' was built under R version 3.6.2"Loading required package: Rcpp
# Warning message:
# "package 'Rcpp' was built under R version 3.6.2"##
# ## Amelia II: Multiple Imputation
# ## (Version 1.7.6, built: 2019-11-24)
# ## Copyright (C) 2005-2020 James Honaker, Gary King and Matthew Blackwell
# ## Refer to http://gking.harvard.edu/amelia/ for more information
# ##
# Warning message:
# "package 'corrgram' was built under R version 3.6.2"Registered S3 method overwritten by 'seriation':
#   method         from
#   reorder.hclust gclus
# Warning message:
# "package 'corrplot' was built under R version 3.6.2"corrplot 0.84 loaded

# %%
missmap(df,main="IMDb Movie Reviews Dataset",col=c("yellow","black"),legend=TRUE)
# Out:
# Plot with title "IMDb Movie Reviews Dataset"

# %% [markdown]
# ## EDA

# %% [markdown]
# Group the movies by their year of release to form an interactive branching relationship plot.

# %%
yt <- df %>% group_by(year) %>% arrange(year) %>% select(year, name) %>% count(year, name)
d3tree(list(root = df2tree(rootname = 'IMDB',struct = as.data.frame(yt)), layout = 'collapse'))
# Out:
# HTML widgets cannot be represented in plain text (need html)

# %% [markdown]
# Number of Movies per year

# %%
ggplot(data = df, aes(x = factor(year))) + geom_bar(stat = 'count') + geom_text(stat = 'count', aes(label = ..count..), vjust = -1) + geom_hline(yintercept = c(0,100,200,300)) + xlab("Year") + ylab("Number of Movies")
# Out:
# plot without title

# %% [markdown]
# Positive trend in number of movie release every year

# %% [markdown]
# Lets have a glance at the Revenue of Movies each year

# %%
ggplot(data = df, aes(x = factor(year), y = gross, fill = factor(year)))+ geom_violin() + xlab("Year") + theme_bw()
# Out:
# plot without title

# %%
year_revenue<-aggregate(Revenue~year, data = df , sum)
ggplot(data = year_revenue, aes(factor(Year), gross, fill = factor(Year))) + 
  geom_bar(stat = 'identity') +
  geom_text(aes(label = gross), vjust = -0.75, cex = 2.5) + 
  xlab("Year") + ylab("Revenue in Millions")
# Out:
# Error in eval(predvars, data, env): object 'Revenue' not found
# Traceback:
#
# 1. aggregate(Revenue ~ year, data = df, sum)
# 2. aggregate.formula(Revenue ~ year, data = df, sum)
# 3. eval(m, parent.frame())
# 4. eval(m, parent.frame())
# 5. stats::model.frame(formula = Revenue ~ year, data = df)
# 6. model.frame.default(formula = Revenue ~ year, data = df)
# 7. eval(predvars, data, env)
# 8. eval(predvars, data, env)

# %% [markdown]
# Revenue of movies is increasing Year by Year

# %% [markdown]
# Let us also see how the ratings affect the Revenue of Movies. But first we must do some processing to club the ratings into intervals.

# %%
newdf=df
rr<- aggregate(Revenue~Rating, data = newdf, sum)
rr$Rating_Interval<- cut(rr$Rating, breaks = seq(from = 1, to = 10, by = 1))
head(rr)
# Out:
#   Rating Revenue Rating_Interval
# 1 1.9     14.17  (1,2]
# 2 2.7      9.35  (2,3]
# 3 3.9     95.46  (3,4]
# 4 4.0     20.76  (3,4]
# 5 4.1    166.15  (4,5]
# 6 4.3    160.27  (4,5]

# %% [markdown]
# Now we can create a boxplot to see how the ratings have affected the Revenue.

# %%
ggplot(data = rr, aes(x = factor(Rating_Interval), y = Revenue, fill = Rating_Interval)) + geom_boxplot() + xlab("Ratings")
# Out:
# plot without title

# %% [markdown]
#  Maximum number of movies were rated between 6-8.

# %% [markdown]
# To further drilldown into this we must also see how many movies were categorised in all interval ranges

# %%
newdf$ri<- cut(newdf$Rating, breaks = seq(1,10, by =1))
rc <- newdf %>% group_by(ri) %>% count(ri)
ggplot(data =  rc, aes(x = ri, y = n)) + geom_bar(stat = 'identity') + 
  xlab("Rating") + ylab("Number of MOvies")
# Out:
# plot without title

# %% [markdown]
# Drama movies tends to dominate the genre.

# %% [markdown]
# Now it is clear that maximum number of movie ratings ranges between 6-8. Hence the Revenue is more for the movies in this range of ratings. This clearly indicates that Revenues is directly proportional to the Ratings received.

# %% [markdown]
# Let us now check the data with respect to Genre of movies

# %%
w<-unique(unlist(strsplit(unique(df$Genre), ",")))
w
# Out:
#  [1] "Action"    "Adventure" "Sci-Fi"    "Mystery"   "Horror"    "Thriller"
#  [7] "Animation" "Comedy"    "Family"    "Fantasy"   "Drama"     "Music"
# [13] "Biography" "Romance"   "History"   "Western"   "Crime"     "War"
# [19] "Musical"   "Sport"

# %%
wc<- function(x){
  length(grep(x, df$Genre))
}

# %%
genrecount<- as.data.frame(sapply(w,wc))
genrecount$genre <- rownames(genrecount)
colnames(genrecount)<- c("count","genre")
genrecount<- arrange(genrecount, desc(count))
genrecount
# Out:
#    count genre
# 1  419   Drama
# 2  277   Action
# 3  250   Comedy
# 4  244   Adventure
# 5  148   Thriller
# 6  126   Crime
# 7  120   Romance
# 8  107   Sci-Fi
# 9   92   Fantasy
# 10  87   Horror
# 11  86   Mystery
# 12  67   Biography
# 13  48   Family
# 14  45   Animation
# 15  25   History
# 16  20   Music
# 17  15   Sport
# 18  10   War
# 19   5   Musical
# 20   4   Western

# %%
ggplot(data = genrecount, aes(x = genre, y = count)) + 
  geom_bar(stat = 'identity') + 
  coord_flip()
# Out:
# plot without title

# %% [markdown]
# From above bar graph it is clear that Drama and Action movies are fairly popular, followed by Comedy and Adventure.

# %%
RevSum<- function(x){
  sum(newdf[(grep(x,newdf$Genre)), "Revenue"])  
}

# %%
rev<-as.data.frame(sapply(w,RevSum))
rev$genre <- rownames(rev)
colnames(rev)[1] <- "Revenue"

# %%
ggplot(data = rev, aes(x = genre, y = Revenue)) + 
  geom_bar(stat = 'identity') +
  xlab("Genre") + ylab("Revenue in Millions") +
  coord_flip()
# Out:
# plot without title

# %% [markdown]
# Above grapgh clearly visualises the distribution of Revenue by Genre of the movie.

# %% [markdown]
# Action and Adventure movies bring most Revenue.

# %% [markdown]
# Top genres in count

# %%
wordcloud(genrecount$genre, genrecount$count, scale = c(3,0.5))
# Out:
# plot without title

# %% [markdown]
# ## CORRELATION

# %%
num.cols=sapply(df,is.numeric)
cor.data=cor(df[,num.cols])
cor.data
# Out:
#           Rank       Year        Runtime    Rating     Votes      Revenue
# Rank       1.0000000 -0.31280879 -0.2547829 -0.2431251 -0.3032835 -0.2731696
# Year      -0.3128088  1.00000000 -0.1019331 -0.1457032 -0.3624448 -0.1291979
# Runtime   -0.2547829 -0.10193313  1.0000000  0.3745658  0.3992982  0.2817207
# Rating    -0.2431251 -0.14570318  0.3745658  1.0000000  0.5174521  0.2171058
# Votes     -0.3032835 -0.36244483  0.3992982  0.5174521  1.0000000  0.6368333
# Revenue   -0.2731696 -0.12919791  0.2817207  0.2171058  0.6368333  1.0000000
# Metascore -0.1959092 -0.06230291  0.2213969  0.6727311  0.3326739  0.1423969
#           Metascore
# Rank      -0.19590921
# Year      -0.06230291
# Runtime    0.22139693
# Rating     0.67273115
# Votes      0.33267386
# Revenue    0.14239688
# Metascore  1.00000000

# %%
corrplot(cor.data,method='color')
# Out:
# Plot with title ""

# %%
corrgram(df,order=TRUE, lower.panel=panel.shade,
         upper.panel=panel.pie, text.panel=panel.txt)
# Out:
# plot without title

# %%
ggplot(df,aes(x=Revenue))+geom_histogram(bins=20,alpha=0.5,fill='blue')+theme_minimal()
# Out:
# plot without title

# %%
library(caTools)

sample=sample.split(df$Rating,SplitRatio = 0.70)

train=subset(df,sample==TRUE)
test=subset(df,sample==FALSE)

# %%
model=lm(Rating~Year+Runtime+Rating+Votes+Revenue+Metascore,train)

summary(model)
# Out:
# Warning message in model.matrix.default(mt, mf, contrasts):
# "the response appeared on the right-hand side and was dropped"Warning message in model.matrix.default(mt, mf, contrasts):
# "problem with term 3 in model.matrix: no columns are assigned"
# Call:
# lm(formula = Rating ~ Year + Runtime + Rating + Votes + Revenue +
#     Metascore, data = train)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.3698 -0.2831  0.0285  0.3397  1.8324
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -6.289e-01  1.650e+01  -0.038    0.970
# Year         2.343e-03  8.201e-03   0.286    0.775
# Runtime      7.678e-03  1.427e-03   5.382 1.07e-07 ***
# Votes        1.766e-06  1.862e-07   9.488  < 2e-16 ***
# Revenue     -1.460e-03  3.275e-04  -4.459 9.90e-06 ***
# Metascore    2.731e-02  1.488e-03  18.351  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.5838 on 581 degrees of freedom
# Multiple R-squared:  0.5772,	Adjusted R-squared:  0.5735
# F-statistic: 158.6 on 5 and 581 DF,  p-value: < 2.2e-16

# %%
res=residuals(model)

res=as.data.frame(res)
head(res)
# Out:
#    res
# 1   0.15416823
# 2  -0.48642995
# 5  -0.15281239
# 6   0.03393058
# 10  0.70108137
# 12  0.79159886

# %%
ggplot(res,aes(res))+geom_histogram(fill='blue',alpha=0.5)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# Plotting Residuals to check whether its Normal Distribution

# %%
Rating.predictions=predict(model,test)
head(Rating.predictions)
# Out:
# Warning message in predict.lm(model, test):
# "prediction from a rank-deficient fit may be misleading"
#        3        4        7        9       11       13
# 6.763349 6.247834 7.854000 7.308839 6.986932 6.685085

# %%
results=cbind(Rating.predictions,test$Rating)
colnames(results)=c('pred','real')
results=as.data.frame(results)
head(results)
# Out:
#    pred     real
# 3  6.763349 7.3
# 4  6.247834 7.2
# 7  7.854000 8.3
# 9  7.308839 7.1
# 11 6.986932 7.5
# 13 6.685085 7.9

# %%
to_zero=function(x){
  if (x<0){
    return(0)
  }else{
    return(x)
  }
}

# %%
results$pred=sapply(results$pred,to_zero)
head(results)
# Out:
#    pred     real
# 3  6.763349 7.3
# 4  6.247834 7.2
# 7  7.854000 8.3
# 9  7.308839 7.1
# 11 6.986932 7.5
# 13 6.685085 7.9

# %%
mse=mean((results$real-results$pred)^2)
print(mse)

mse^0.5
# Out:
# [1] 0.3006565
# [1] 0.5483215

# %%
SSE=sum((results$pred-results$real)^2)
SST=sum((mean(df$Rating)-results$real)^2)
R2=1-SSE/SST
R2
# Out:
# [1] 0.5724089
